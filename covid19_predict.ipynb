# %% [markdown]
# # Predictive Analytics for Coronavirus Spread Using Bayesian Inference
# #### Author: Bohdan Pavlyshenko (LinkedIn: https://www.linkedin.com/in/bpavlyshenko/  GitHub: https://github.com/pavlyshenko/coronavirus)

# %%
from covid19_funcs import *
# %matplotlib inline

# %% [markdown]
# #### Set up options

# %%
# File name of historical data file
data_filename='data/train.csv'

# Name of fields in the hystorical data frame for in the following order: 
# date, region, confirmed cases, fatalities
field_names=['Date','Country_Region','ConfirmedCases','Fatalities']

# List of regions for prediction
region_list=['China','US','Italy','Spain','Iran','Germany','France']

# Number of days for prediction
n_days_predict=25

# %% [markdown]
# #### Load data

# %%
df=pd.read_csv(data_filename)[field_names]
df.columns=['date',region_field,cases_field,fatalities_field]
df.head()
# Out:
#          date       region  cases  deaths
# 0  2020-01-22  Afghanistan    0.0     0.0
# 1  2020-01-23  Afghanistan    0.0     0.0
# 2  2020-01-24  Afghanistan    0.0     0.0
# 3  2020-01-25  Afghanistan    0.0     0.0
# 4  2020-01-26  Afghanistan    0.0     0.0

# %% [markdown]
# #### Compile model

# %%
# This function should be launched only once for new model
compile_model(model_logistic, model_file)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_d985c43dd0d3315f006d6331e82d0578 NOW.
# /anaconda3/lib/python3.6/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/16/01w8_c7d29dfb6zzz2l20sr04r07j1/T/tmp5wlrb4gz/stanfit4anon_model_d985c43dd0d3315f006d6331e82d0578_8622957866803795973.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Done

# %% [markdown]
# #### Get prediction for one region

# %%
df_res=get_prediction(df,n_days_predict=25, target_field='cases', region_value='China', img_file_name='p1.png')
df_res=get_prediction(df,n_days_predict=25, target_field='deaths', region_value='China', img_file_name='p1.png')
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# Time Series size: 66
# Model parameters: alpha=0.811 (sd:0.004, beta=1.548(sd:0.043),    t0=2.541(sd:0.021)
# Time Series size: 66
# Model parameters: alpha=0.032 (sd:0.0, beta=1.089(sd:0.017),    t0=3.464(sd:0.017)

# %% [markdown]
# #### Get prediction for list of regions

# %%
region_list=['China','US','Italy','Spain','Iran','Germany','France']
get_regions_prediction(df,region_list,target_field='cases')
get_regions_prediction(df,region_list,target_field='deaths')
# Out:
# China:
# Time Series size: 66
# Model parameters: alpha=0.811 (sd:0.004, beta=1.549(sd:0.043),    t0=2.541(sd:0.021)
# US:
# Time Series size: 66
# Model parameters: alpha=2.155 (sd:0.11, beta=2.253(sd:0.042),    t0=9.342(sd:0.041)
# Italy:
# Time Series size: 66
# Model parameters: alpha=1.193 (sd:0.02, beta=1.359(sd:0.017),    t0=8.602(sd:0.027)
# Spain:
# Time Series size: 66
# Model parameters: alpha=1.696 (sd:0.144, beta=1.541(sd:0.035),    t0=9.579(sd:0.091)
# Iran:
# Time Series size: 66
# Model parameters: alpha=0.397 (sd:0.023, beta=1.066(sd:0.049),    t0=8.245(sd:0.125)
# Germany:
# Time Series size: 66
# Model parameters: alpha=0.875 (sd:0.061, beta=1.65(sd:0.052),    t0=9.126(sd:0.081)
# France:
# Time Series size: 66
# Model parameters: alpha=0.725 (sd:0.043, beta=1.408(sd:0.027),    t0=9.407(sd:0.073)
# China:
# Time Series size: 66
# Model parameters: alpha=0.032 (sd:0.0, beta=1.089(sd:0.017),    t0=3.463(sd:0.017)
# US:
# Time Series size: 66
# WARNING:pystan:3662 of 7500 iterations saturated the maximum tree depth of 10 (48.82666666666667%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# Model parameters: alpha=1.281 (sd:0.724, beta=1.879(sd:0.015),    t0=11.526(sd:0.345)
# Italy:
# Time Series size: 66
# Model parameters: alpha=0.135 (sd:0.003, beta=1.525(sd:0.021),    t0=8.835(sd:0.03)
# Spain:
# Time Series size: 66
# Model parameters: alpha=0.113 (sd:0.004, beta=2.09(sd:0.028),    t0=9.37(sd:0.032)
# Iran:
# Time Series size: 66
# Model parameters: alpha=0.029 (sd:0.0, beta=1.472(sd:0.019),    t0=8.317(sd:0.021)
# Germany:
# Time Series size: 66
# WARNING:pystan:3615 of 7500 iterations saturated the maximum tree depth of 10 (48.2%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# Model parameters: alpha=1.088 (sd:0.822, beta=1.804(sd:0.029),    t0=12.205(sd:0.714)
# France:
# Time Series size: 66
# Model parameters: alpha=0.047 (sd:0.005, beta=2.094(sd:0.063),    t0=9.424(sd:0.08)
